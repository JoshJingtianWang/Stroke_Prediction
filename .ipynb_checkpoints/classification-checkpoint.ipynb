# %% [markdown]
# # Stroke Prediction

# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score, roc_auc_score, precision_score, recall_score, accuracy_score
from sklearn.metrics import brier_score_loss, make_scorer
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.calibration import CalibratedClassifierCV
from sklearn.preprocessing import PolynomialFeatures
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

from xgboost import XGBClassifier

from imblearn.pipeline import Pipeline
from imblearn import under_sampling
from imblearn import over_sampling

import seaborn as sns
import matplotlib.pyplot as plt

# %%
import streamlit as st

# %%
import pickle

# %%
pickle.__version__()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [762], in <cell line: 1>()
# ----> 1 pickle.__version__()
#
# AttributeError: module 'pickle' has no attribute '__version__'

# %%
df = pd.read_csv('healthcare-dataset-stroke-data.csv')

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
df.gender.value_counts()
# Out:
# Female    2994
# Male      2115
# Other        1
# Name: gender, dtype: int64

# %%
#drop the one missing value in 'gender'
df = df[df['gender']!='Other']
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# #### Imputing 'unknown' class in smoking_status with KNNImputer

# %%
df.smoking_status.value_counts()
# Out:
# never smoked       1892
# Unknown            1544
# formerly smoked     884
# smokes              789
# Name: smoking_status, dtype: int64

# %%
#mapping categorical values to numeric
df['smoking_map']=df.smoking_status.map({'never smoked':0,'formerly smoked':1,'smokes':2})

# %%
#get dummy variables
genderdummy=pd.get_dummies(df["gender"], drop_first=True)
marrieddummy=pd.get_dummies(df["ever_married"], prefix="married", drop_first=True)
workdummy=pd.get_dummies(df["work_type"], drop_first=True)
residencedummy=pd.get_dummies(df["Residence_type"], drop_first=True)

# %%
colstokeep=["age","hypertension","heart_disease",'avg_glucose_level','bmi','stroke','smoking_map']

# %%
dummydf = df[colstokeep].join(genderdummy).join(marrieddummy).join(workdummy).join(residencedummy)

# %%
dummydf.columns
# Out:
# Index(['age', 'hypertension', 'heart_disease', 'avg_glucose_level', 'bmi',
#        'stroke', 'smoking_map', 'Male', 'married_Yes', 'Never_worked',
#        'Private', 'Self-employed', 'children', 'Urban'],
#       dtype='object')

# %%
#imputing missing values by KNNimputation
imputer = KNNImputer(n_neighbors=1)
df_filled=imputer.fit_transform(dummydf)

# %%
df_filled=pd.DataFrame(df_filled,columns=dummydf.columns)

# %%
df['smoking']=df_filled['smoking_map']
df['bmi']=df_filled['bmi']

# %%
df.drop(['smoking_status', 'smoking_map','id'], axis=1, inplace=True)

# %%
#convert smoking_status back to categorical
df['smoking']=df.smoking.map({0:'never smoked',1:'formerly smoked',2:'smokes'})

# %%
#check class imbalance
df.stroke.hist()
plt.show()

# %%
#check class imbalance
sns.histplot(data=df.stroke)

plt.savefig("hist.png",
            bbox_inches="tight",
           transparent=True); #avoid cutting off labels

# %%
#check class imbalance
sns.scatterplot(x="avg_glucose_level",
                    y="age",
                    data=df,
                    hue="stroke",
               alpha=0.5)
plt.show()

# %%
sns.pairplot(df[['age','hypertension','avg_glucose_level','bmi','stroke']], hue='stroke',
             plot_kws={'alpha':0.4})

# %%
df
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1     Female  61.0             0              0          Yes  Self-employed
# 2       Male  80.0             0              1          Yes        Private
# 3     Female  49.0             0              0          Yes        Private
# 4     Female  79.0             1              0          Yes  Self-employed
# ...      ...   ...           ...            ...          ...            ...
# 5104  Female  80.0             1              0          Yes        Private
# 5105  Female  81.0             0              0          Yes  Self-employed
# 5106  Female  35.0             0              0          Yes  Self-employed
# 5107    Male  51.0             0              0          Yes        Private
# 5108  Female  44.0             0              0          Yes       Govt_job
#
#      Residence_type  avg_glucose_level   bmi  stroke          smoking
# 0             Urban             228.69  36.6       1  formerly smoked
# 1             Rural             202.21  33.8       1     never smoked
# 2             Rural             105.92  32.5       1     never smoked
# 3             Urban             171.23  34.4       1           smokes
# 4             Rural             174.12  24.0       1     never smoked
# ...             ...                ...   ...     ...              ...
# 5104          Urban              83.75  25.0       0     never smoked
# 5105          Urban             125.20  40.0       0     never smoked
# 5106          Rural              82.99  30.6       0     never smoked
# 5107          Rural             166.29  25.6       0  formerly smoked
# 5108          Urban              85.28  26.2       0  formerly smoked
#
# [5109 rows x 11 columns]

# %% [markdown]
# ## Logistic Regression

# %%
#splitting data with stratify
X_train, X_test, y_train, y_test = train_test_split(df.drop('stroke', axis=1), df_filled.loc[:,'stroke'],
                                                    test_size = 0.2, random_state=42, 
                                                    stratify = df_filled.loc[:,'stroke'])

# %%
y_train.value_counts()
# Out:
# 0.0    3888
# 1.0     199
# Name: stroke, dtype: int64

# %%
probabilities = [0.0487 for _ in range(len(y_train))]
brier_ref = brier_score_loss(y_train, probabilities)
def brier_skill_score(y_true, y_predicted):
    # calculate the brier score
    bs = brier_score_loss(y_true, y_predicted)
    # calculate skill score
    return 1.0 - (bs / brier_ref)

BSS_scorer = make_scorer(brier_skill_score, greater_is_better=True, needs_proba=True)

# %%
brier_ref
# Out:
# 0.04632016076094936

# %%
#preprocessing pipeline for onehot encoding during CV
def fit_data_preprocessing_pipeline(X_train):
    
    # first select the numerical and categorical columns
    cat_cols = X_train.select_dtypes('object').columns.tolist()
    cont_cols = X_train.select_dtypes('number').columns.tolist()


    #build data processing pipeline
    cat_pipeline = Pipeline([
                ('encode',OneHotEncoder(handle_unknown='ignore', sparse=False))
    ])

    cont_pipeline = Pipeline([
                
                ('scale',StandardScaler())
    ])

    columntransformer = ColumnTransformer([
        ('cat', cat_pipeline, cat_cols),
        ('num', cont_pipeline, cont_cols)
        #('poly',PolynomialFeatures(degree =2))
    ])
    
    preprocessor = ColumnTransformer([
        ('cat', cat_pipeline, cat_cols),
        ('num', cont_pipeline, cont_cols)
        #('poly',PolynomialFeatures(degree =2))
    ])
    
    preprocessor.fit(X_train)
    
    #cat_columns = preprocessor.named_transformers_['cat']['encode'].get_feature_names(cat_cols)
    #transformed_columns = np.append(cat_columns, cont_cols)
    
    return preprocessor

# %%
preprocessor = fit_data_preprocessing_pipeline(X_train)

# %%
polynomial = PolynomialFeatures(degree=2)

# %%
#get feature names after onehotencoding and polynomial
onehotencodeddf=pd.DataFrame(preprocessor.fit_transform(X_train),columns=preprocessor.get_feature_names_out())
polynomial_df = PolynomialFeatures(degree=2).fit(onehotencodeddf)
polynomial_df.get_feature_names_out()
# Out:
# array(['1', 'cat__gender_Female', 'cat__gender_Male',
#        'cat__ever_married_No', 'cat__ever_married_Yes',
#        'cat__work_type_Govt_job', 'cat__work_type_Never_worked',
#        'cat__work_type_Private', 'cat__work_type_Self-employed',
#        'cat__work_type_children', 'cat__Residence_type_Rural',
#        'cat__Residence_type_Urban', 'cat__smoking_formerly smoked',
#        'cat__smoking_never smoked', 'cat__smoking_smokes', 'num__age',
#        'num__hypertension', 'num__heart_disease',
#        'num__avg_glucose_level', 'num__bmi', 'cat__gender_Female^2',
#        'cat__gender_Female cat__gender_Male',
#        'cat__gender_Female cat__ever_married_No',
#        'cat__gender_Female cat__ever_married_Yes',
#        'cat__gender_Female cat__work_type_Govt_job',
#        'cat__gender_Female cat__work_type_Never_worked',
#        'cat__gender_Female cat__work_type_Private',
#        'cat__gender_Female cat__work_type_Self-employed',
#        'cat__gender_Female cat__work_type_children',
#        'cat__gender_Female cat__Residence_type_Rural',
#        'cat__gender_Female cat__Residence_type_Urban',
#        'cat__gender_Female cat__smoking_formerly smoked',
#        'cat__gender_Female cat__smoking_never smoked',
#        'cat__gender_Female cat__smoking_smokes',
#        'cat__gender_Female num__age',
#        'cat__gender_Female num__hypertension',
#        'cat__gender_Female num__heart_disease',
#        'cat__gender_Female num__avg_glucose_level',
#        'cat__gender_Female num__bmi', 'cat__gender_Male^2',
#        'cat__gender_Male cat__ever_married_No',
#        'cat__gender_Male cat__ever_married_Yes',
#        'cat__gender_Male cat__work_type_Govt_job',
#        'cat__gender_Male cat__work_type_Never_worked',
#        'cat__gender_Male cat__work_type_Private',
#        'cat__gender_Male cat__work_type_Self-employed',
#        'cat__gender_Male cat__work_type_children',
#        'cat__gender_Male cat__Residence_type_Rural',
#        'cat__gender_Male cat__Residence_type_Urban',
#        'cat__gender_Male cat__smoking_formerly smoked',
#        'cat__gender_Male cat__smoking_never smoked',
#        'cat__gender_Male cat__smoking_smokes',
#        'cat__gender_Male num__age', 'cat__gender_Male num__hypertension',
#        'cat__gender_Male num__heart_disease',
#        'cat__gender_Male num__avg_glucose_level',
#        'cat__gender_Male num__bmi', 'cat__ever_married_No^2',
#        'cat__ever_married_No cat__ever_married_Yes',
#        'cat__ever_married_No cat__work_type_Govt_job',
#        'cat__ever_married_No cat__work_type_Never_worked',
#        'cat__ever_married_No cat__work_type_Private',
#        'cat__ever_married_No cat__work_type_Self-employed',
#        'cat__ever_married_No cat__work_type_children',
#        'cat__ever_married_No cat__Residence_type_Rural',
#        'cat__ever_married_No cat__Residence_type_Urban',
#        'cat__ever_married_No cat__smoking_formerly smoked',
#        'cat__ever_married_No cat__smoking_never smoked',
#        'cat__ever_married_No cat__smoking_smokes',
#        'cat__ever_married_No num__age',
#        'cat__ever_married_No num__hypertension',
#        'cat__ever_married_No num__heart_disease',
#        'cat__ever_married_No num__avg_glucose_level',
#        'cat__ever_married_No num__bmi', 'cat__ever_married_Yes^2',
#        'cat__ever_married_Yes cat__work_type_Govt_job',
#        'cat__ever_married_Yes cat__work_type_Never_worked',
#        'cat__ever_married_Yes cat__work_type_Private',
#        'cat__ever_married_Yes cat__work_type_Self-employed',
#        'cat__ever_married_Yes cat__work_type_children',
#        'cat__ever_married_Yes cat__Residence_type_Rural',
#        'cat__ever_married_Yes cat__Residence_type_Urban',
#        'cat__ever_married_Yes cat__smoking_formerly smoked',
#        'cat__ever_married_Yes cat__smoking_never smoked',
#        'cat__ever_married_Yes cat__smoking_smokes',
#        'cat__ever_married_Yes num__age',
#        'cat__ever_married_Yes num__hypertension',
#        'cat__ever_married_Yes num__heart_disease',
#        'cat__ever_married_Yes num__avg_glucose_level',
#        'cat__ever_married_Yes num__bmi', 'cat__work_type_Govt_job^2',
#        'cat__work_type_Govt_job cat__work_type_Never_worked',
#        'cat__work_type_Govt_job cat__work_type_Private',
#        'cat__work_type_Govt_job cat__work_type_Self-employed',
#        'cat__work_type_Govt_job cat__work_type_children',
#        'cat__work_type_Govt_job cat__Residence_type_Rural',
#        'cat__work_type_Govt_job cat__Residence_type_Urban',
#        'cat__work_type_Govt_job cat__smoking_formerly smoked',
#        'cat__work_type_Govt_job cat__smoking_never smoked',
#        'cat__work_type_Govt_job cat__smoking_smokes',
#        'cat__work_type_Govt_job num__age',
#        'cat__work_type_Govt_job num__hypertension',
#        'cat__work_type_Govt_job num__heart_disease',
#        'cat__work_type_Govt_job num__avg_glucose_level',
#        'cat__work_type_Govt_job num__bmi',
#        'cat__work_type_Never_worked^2',
#        'cat__work_type_Never_worked cat__work_type_Private',
#        'cat__work_type_Never_worked cat__work_type_Self-employed',
#        'cat__work_type_Never_worked cat__work_type_children',
#        'cat__work_type_Never_worked cat__Residence_type_Rural',
#        'cat__work_type_Never_worked cat__Residence_type_Urban',
#        'cat__work_type_Never_worked cat__smoking_formerly smoked',
#        'cat__work_type_Never_worked cat__smoking_never smoked',
#        'cat__work_type_Never_worked cat__smoking_smokes',
#        'cat__work_type_Never_worked num__age',
#        'cat__work_type_Never_worked num__hypertension',
#        'cat__work_type_Never_worked num__heart_disease',
#        'cat__work_type_Never_worked num__avg_glucose_level',
#        'cat__work_type_Never_worked num__bmi', 'cat__work_type_Private^2',
#        'cat__work_type_Private cat__work_type_Self-employed',
#        'cat__work_type_Private cat__work_type_children',
#        'cat__work_type_Private cat__Residence_type_Rural',
#        'cat__work_type_Private cat__Residence_type_Urban',
#        'cat__work_type_Private cat__smoking_formerly smoked',
#        'cat__work_type_Private cat__smoking_never smoked',
#        'cat__work_type_Private cat__smoking_smokes',
#        'cat__work_type_Private num__age',
#        'cat__work_type_Private num__hypertension',
#        'cat__work_type_Private num__heart_disease',
#        'cat__work_type_Private num__avg_glucose_level',
#        'cat__work_type_Private num__bmi',
#        'cat__work_type_Self-employed^2',
#        'cat__work_type_Self-employed cat__work_type_children',
#        'cat__work_type_Self-employed cat__Residence_type_Rural',
#        'cat__work_type_Self-employed cat__Residence_type_Urban',
#        'cat__work_type_Self-employed cat__smoking_formerly smoked',
#        'cat__work_type_Self-employed cat__smoking_never smoked',
#        'cat__work_type_Self-employed cat__smoking_smokes',
#        'cat__work_type_Self-employed num__age',
#        'cat__work_type_Self-employed num__hypertension',
#        'cat__work_type_Self-employed num__heart_disease',
#        'cat__work_type_Self-employed num__avg_glucose_level',
#        'cat__work_type_Self-employed num__bmi',
#        'cat__work_type_children^2',
#        'cat__work_type_children cat__Residence_type_Rural',
#        'cat__work_type_children cat__Residence_type_Urban',
#        'cat__work_type_children cat__smoking_formerly smoked',
#        'cat__work_type_children cat__smoking_never smoked',
#        'cat__work_type_children cat__smoking_smokes',
#        'cat__work_type_children num__age',
#        'cat__work_type_children num__hypertension',
#        'cat__work_type_children num__heart_disease',
#        'cat__work_type_children num__avg_glucose_level',
#        'cat__work_type_children num__bmi', 'cat__Residence_type_Rural^2',
#        'cat__Residence_type_Rural cat__Residence_type_Urban',
#        'cat__Residence_type_Rural cat__smoking_formerly smoked',
#        'cat__Residence_type_Rural cat__smoking_never smoked',
#        'cat__Residence_type_Rural cat__smoking_smokes',
#        'cat__Residence_type_Rural num__age',
#        'cat__Residence_type_Rural num__hypertension',
#        'cat__Residence_type_Rural num__heart_disease',
#        'cat__Residence_type_Rural num__avg_glucose_level',
#        'cat__Residence_type_Rural num__bmi',
#        'cat__Residence_type_Urban^2',
#        'cat__Residence_type_Urban cat__smoking_formerly smoked',
#        'cat__Residence_type_Urban cat__smoking_never smoked',
#        'cat__Residence_type_Urban cat__smoking_smokes',
#        'cat__Residence_type_Urban num__age',
#        'cat__Residence_type_Urban num__hypertension',
#        'cat__Residence_type_Urban num__heart_disease',
#        'cat__Residence_type_Urban num__avg_glucose_level',
#        'cat__Residence_type_Urban num__bmi',
#        'cat__smoking_formerly smoked^2',
#        'cat__smoking_formerly smoked cat__smoking_never smoked',
#        'cat__smoking_formerly smoked cat__smoking_smokes',
#        'cat__smoking_formerly smoked num__age',
#        'cat__smoking_formerly smoked num__hypertension',
#        'cat__smoking_formerly smoked num__heart_disease',
#        'cat__smoking_formerly smoked num__avg_glucose_level',
#        'cat__smoking_formerly smoked num__bmi',
#        'cat__smoking_never smoked^2',
#        'cat__smoking_never smoked cat__smoking_smokes',
#        'cat__smoking_never smoked num__age',
#        'cat__smoking_never smoked num__hypertension',
#        'cat__smoking_never smoked num__heart_disease',
#        'cat__smoking_never smoked num__avg_glucose_level',
#        'cat__smoking_never smoked num__bmi', 'cat__smoking_smokes^2',
#        'cat__smoking_smokes num__age',
#        'cat__smoking_smokes num__hypertension',
#        'cat__smoking_smokes num__heart_disease',
#        'cat__smoking_smokes num__avg_glucose_level',
#        'cat__smoking_smokes num__bmi', 'num__age^2',
#        'num__age num__hypertension', 'num__age num__heart_disease',
#        'num__age num__avg_glucose_level', 'num__age num__bmi',
#        'num__hypertension^2', 'num__hypertension num__heart_disease',
#        'num__hypertension num__avg_glucose_level',
#        'num__hypertension num__bmi', 'num__heart_disease^2',
#        'num__heart_disease num__avg_glucose_level',
#        'num__heart_disease num__bmi', 'num__avg_glucose_level^2',
#        'num__avg_glucose_level num__bmi', 'num__bmi^2'], dtype=object)

# %%
#Logistic Regression Base

# std_scale = StandardScaler()

# X_train_scaled = std_scale.fit_transform(X_train)
# X_test_scaled = std_scale.fit_transform(X_test)

lr = LogisticRegression(max_iter=500)

cv_pipe = Pipeline([
('preprocessor', preprocessor),
#('poly', polynomial),
('lr', lr)])

scores = cross_validate(cv_pipe, X_train, y_train, cv=5, scoring=(BSS_scorer), return_estimator=True)

# %%
#mean BSS of lr base
np.mean(scores['test_score'])
# Out:
# 0.07479560732782835

# %%
scores['estimator'][0].predict_proba(X_test)[:,1]
# Out:
# array([0.00991368, 0.00183048, 0.05302101, ..., 0.06390323, 0.00016867,
#        0.00542669])

# %%
#brier score on testing set
bs=brier_score_loss(y_test, scores['estimator'][0].predict_proba(X_test)[:,1])
1.0 - (bs / brier_ref)
# Out:
# 0.06820342770380172

# %%
#get feature names after onehotencoding and polynomial
onehotencodeddf=pd.DataFrame(preprocessor.fit_transform(X_train),columns=preprocessor.get_feature_names_out())
polynomial = PolynomialFeatures(degree=2).fit(onehotencodeddf)
polynomial.get_feature_names_out()

# %%
#get coefficients
fitted_lr = scores['estimator'][0].named_steps
fitted_lr['lr'].coef_

# %%
#defining Brier Skill Score
probabilities = [0.0487 for _ in range(len(y_train))]
brier_ref = brier_score_loss(y_train, probabilities)
def brier_skill_score(y_true, y_predicted):
    # calculate the brier score
    bs = brier_score_loss(y_true, y_predicted)
    # calculate skill score
    return 1.0 - (bs / brier_ref)

BSS_scorer = make_scorer(brier_score_loss, greater_is_better=True, needs_proba=True)

# %%
#Logistic Regression GridSearch

ratios=[]
for n in np.arange(1,6):
    # setup for the ratio argument of RandomOverSampler initialization
    n_pos = np.sum(y_train == 1)
    n_neg = np.sum(y_train == 0)
    ratios.append({1 : n_pos * n, 0 : n_neg})

classweights=[]
for n in np.arange(1,11,3):
    classweights.append({1 : n, 0 : 1})

penalty=['l1', 'l2'] 
    
lr_pipe = Pipeline([
        ('preprocessor', preprocessor),
        #('poly', polynomial),
        #('oversampling', over_sampling.SMOTE()),
        #('undersampling', under_sampling.NeighbourhoodCleaningRule()),
        ('lr', LogisticRegression(solver='liblinear'))
        ])

params = [{
         #'oversampling__sampling_strategy':ratios,
         #'oversampling__random_state':[42],
#         'undersampling__sampling_strategy':['majority'],
#         'undersampling__n_neighbors':np.arange(1,5),
        'lr__C': np.logspace(0.001, 4, 4),
        'lr__class_weight':classweights,
        'lr__penalty':penalty
        }]

gs_lr = GridSearchCV(lr_pipe,
                    param_grid=params,
                    scoring=BSS_scorer,
                    refit=True,
                    cv=5,
                    n_jobs=-1,
                    error_score='raise',
                    verbose=4)

gs_lr.fit(X_train, y_train)
#y_pred_gs=gs_lr.predict(X_test)

print(gs_lr.best_params_)
print(gs_lr.best_score_)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# {'lr__C': 1.0023052380778996, 'lr__class_weight': {1: 1, 0: 1}, 'lr__penalty': 'l1'}
# 0.0763830719817498

# %%
gs_lr.predict_proba(X_train)[:,1]
# Out:
# array([0.01902266, 0.00654649, 0.00821483, ..., 0.05110687, 0.00602704,
#        0.01543456])

# %%
#brier score on testing set
bs=brier_score_loss(y_train, gs_lr.predict_proba(X_train)[:,1])
1.0 - (bs / brier_ref)
# Out:
# 0.08776006100523959

# %%
#get coefficients
coef_dict=dict(zip(polynomial_df.get_feature_names_out(),gs_lr.best_estimator_['lr'].coef_[0]))
coef_df=pd.DataFrame(coef_dict.items(),columns=['Feature','Coefficient'])
coef_df=coef_df.sort_values('Coefficient',ascending=False)

# %%
coef_df
# Out:
#                          Feature  Coefficient
# 14           cat__smoking_smokes     1.609708
# 17            num__heart_disease     0.180805
# 15                      num__age     0.145335
# 16             num__hypertension     0.037567
# 18        num__avg_glucose_level     0.024384
# 13     cat__smoking_never smoked     0.000000
# 2               cat__gender_Male     0.000000
# 4          cat__ever_married_Yes     0.000000
# 5        cat__work_type_Govt_job     0.000000
# 6    cat__work_type_Never_worked     0.000000
# 8   cat__work_type_Self-employed     0.000000
# 1             cat__gender_Female     0.000000
# 10     cat__Residence_type_Rural     0.000000
# 0                              1    -0.048514
# 11     cat__Residence_type_Urban    -0.078275
# 9        cat__work_type_children    -0.097991
# 7         cat__work_type_Private    -0.223030
# 12  cat__smoking_formerly smoked    -0.225709
# 3           cat__ever_married_No    -0.247685

# %%
#coefficient plot
params = {"ytick.color" : "black",
          "xtick.color" : "black",
          "axes.labelcolor" : "black",
          "axes.edgecolor" : "black"}
plt.rcParams.update(params) #changes text color

plt.figure(figsize = (20,8),facecolor='white')
sns.set_context("talk")
coplot=sns.barplot(x='Feature',y='Coefficient',data=coef_df, color='#7f94a1')
#coplot.set_xticklabels([])
plt.xticks(rotation=45)

plt.show()
#coplot.set_facecolor("white") #set color around plot to be white

coplot.figure.savefig("coef_plot.png",
                      bbox_inches="tight",
                      transparent=True
                     ); #avoid cutting off labels

# %% [markdown]
# ## KNN

# %%
#KNN base
calibrated_knn = CalibratedClassifierCV(base_estimator=KNeighborsClassifier(), method='sigmoid') 

cv_pipe = Pipeline([
        ('preprocessor', preprocessor),
        #('poly', polynomial),
        ('calibrated_knn', calibrated_knn)
        ])

scores = cross_validate(cv_pipe, X_train, y_train, cv=5, scoring=(BSS_scorer),return_estimator = True)

# %%
#mean BSS of KNN base
np.mean(scores['test_score'])
# Out:
# 0.01267309849672904

# %%
#KNN GridSearchCV calibrated

calibrated_knn = CalibratedClassifierCV(base_estimator=KNeighborsClassifier())        

method=['sigmoid', 'isotonic']  

ratios=[]
for n in np.arange(1,8,2):
    # setup for the ratio argument of RandomOverSampler initialization
    n_pos = np.sum(y_train == 1)
    n_neg = np.sum(y_train == 0)
    ratios.append({1 : n_pos * n, 0 : n_neg})

knn_pipe = Pipeline([
        ('preprocessor', preprocessor),
        #('poly', polynomial),
        ('oversampling', over_sampling.SMOTE()),
        #('undersampling', under_sampling.NeighbourhoodCleaningRule()),
        ('calibrated_knn', calibrated_knn)
        ])

params = [{
        'oversampling__sampling_strategy':ratios,
        'oversampling__random_state':[42],
        #'undersampling__sampling_strategy':['majority'],
        #'undersampling__n_neighbors':np.arange(1,10),
        'calibrated_knn__base_estimator__n_neighbors': np.arange(50, 150, 5),
        'calibrated_knn__base_estimator__weights':['uniform', 'distance'],
        'calibrated_knn__method':method
          }]

gs_knn = RandomizedSearchCV(
                    knn_pipe,
                    param_distributions=params,
                    scoring=BSS_scorer,
                    refit=True,
                    n_iter=30,
                    random_state=42,
                    cv=5,
                    n_jobs=-1,
                    verbose=4
                    )

gs_knn.fit(X_train, y_train)
y_pred_gs=gs_knn.predict(X_test)

print(gs_knn.best_params_)
print(gs_knn.best_score_)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# {'oversampling__sampling_strategy': {1: 199, 0: 3888}, 'oversampling__random_state': 42, 'calibrated_knn__method': 'sigmoid', 'calibrated_knn__base_estimator__weights': 'uniform', 'calibrated_knn__base_estimator__n_neighbors': 120}
# 0.04252368465489762

# %%
#brier score on testing set
bs=brier_score_loss(y_test, gs_knn.predict_proba(X_test)[:,1])
1.0 - (bs / brier_ref)
# Out:
# 0.04803988436773832

# %%
#Reliability Diagram
#https://towardsdatascience.com/how-to-enforce-the-outcome-of-your-ml-classifiers-b5f6163d68c2
from sklearn.calibration import calibration_curve

y_pred_gs_proba=gs_knn.predict_proba(X_test)
observed_pos_frequency, mean_pred_proba  = calibration_curve(y_test, y_pred_gs_proba[:,1], 
                                                             n_bins=50, strategy='uniform')
plt.plot(mean_pred_proba, observed_pos_frequency)
plt.plot([0, 1], [0, 1])
plt.xlim(0,1)
plt.show()

# %% [markdown]
# ## RandomForest

# %%
#RandomForest base

calibrated_rf = CalibratedClassifierCV(base_estimator=RandomForestClassifier(random_state=42))

cv_pipe = Pipeline([
('preprocessor', preprocessor),
#('poly', polynomial),
('calibrated_rf', calibrated_rf)])

scores = cross_validate(cv_pipe, X_train, y_train, cv=5, scoring=(BSS_scorer))

# %%
#mean BSS of RF base
np.mean(scores['test_score'])
# Out:
# 0.03412472457676037

# %%
#RandomForest RandomSearchCV calibrated

classweights = []
for n in np.arange(1,11):
    classweights.append({1 : n, 0 : 1})    

max_features = [None, 'sqrt', 'log2']
    
n_estimators = np.logspace(1.5, 3.5, num=8, dtype = int)

# Maximum number of levels in tree
max_depth = np.linspace(10, 110, num = 5, dtype = int)
max_depth = np.append(max_depth, None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]

calibrated_rf = CalibratedClassifierCV(base_estimator=RandomForestClassifier(random_state=42))        

method=['sigmoid', 'isotonic']  

rf_pipe = Pipeline([
        ('preprocessor', preprocessor),
        ('poly', polynomial),
        #('oversampling', over_sampling.SMOTE()),
        #('undersampling', under_sampling.NeighbourhoodCleaningRule()),
        ('calibrated_rf', calibrated_rf)
        ])

params = [{
        #'oversampling__sampling_strategy':ratios,
        #'oversampling__random_state':[42],
        #'undersampling__sampling_strategy':['majority'],
        #'undersampling__n_neighbors':np.arange(1,7,2),
        'calibrated_rf__base_estimator__n_estimators': np.arange(30,150,3),
        'calibrated_rf__base_estimator__max_features': max_features,
        'calibrated_rf__base_estimator__max_depth': max_depth,
        'calibrated_rf__base_estimator__min_samples_split': min_samples_split,
        'calibrated_rf__base_estimator__min_samples_leaf': min_samples_leaf,
        'calibrated_rf__base_estimator__class_weight':classweights,
        'calibrated_rf__method':method
          }]

rd_rf = RandomizedSearchCV(rf_pipe,
                            param_distributions=params,
                            scoring=BSS_scorer,
                            refit=True,
                            cv=5,
                            n_iter=20,
                            n_jobs=-1,
                           random_state=42,
                          verbose=2)

rd_rf.fit(X_train, y_train)
y_pred_gs=rd_rf.predict(X_test)

print(rd_rf.best_params_)
print(rd_rf.best_score_)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# {'calibrated_rf__method': 'isotonic', 'calibrated_rf__base_estimator__n_estimators': 63, 'calibrated_rf__base_estimator__min_samples_split': 10, 'calibrated_rf__base_estimator__min_samples_leaf': 1, 'calibrated_rf__base_estimator__max_features': 'sqrt', 'calibrated_rf__base_estimator__max_depth': 35, 'calibrated_rf__base_estimator__class_weight': {1: 2, 0: 1}}
# 0.07145140566932277

# %%
#RandomForest GridSearchCV calibrated

classweights = []
for n in np.arange(3,6):
    classweights.append({1 : n, 0 : 1})    

max_features = [None, 'sqrt', 'log2']
    
n_estimators = np.logspace(1.5, 3.5, num=8, dtype = int)

# Maximum number of levels in tree
max_depth = np.linspace(15, 50, num = 5, dtype = int)
max_depth = np.append(max_depth, None)
# Minimum number of samples required to split a node
min_samples_split = [5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2]

calibrated_rf = CalibratedClassifierCV(base_estimator=RandomForestClassifier(random_state=42))        

method=['sigmoid', 'isotonic']  

rf_pipe = Pipeline([
        ('preprocessor', preprocessor),
        #('poly', polynomial),
        #('oversampling', over_sampling.SMOTE()),
        #('undersampling', under_sampling.NeighbourhoodCleaningRule()),
        ('calibrated_rf', calibrated_rf)
        ])

params = [{
        #'oversampling__sampling_strategy':ratios,
        #'oversampling__random_state':[42],
        #'undersampling__sampling_strategy':['majority'],
        #'undersampling__n_neighbors':np.arange(140,190,5),
        'calibrated_rf__base_estimator__n_estimators': np.arange(68,71,2),
        'calibrated_rf__base_estimator__max_features': ['sqrt'],
        'calibrated_rf__base_estimator__max_depth': np.arange(18,26,2),
        'calibrated_rf__base_estimator__min_samples_split': [11],
        'calibrated_rf__base_estimator__min_samples_leaf': [1],
        'calibrated_rf__base_estimator__class_weight':classweights,
        'calibrated_rf__method':['isotonic']
          }]

gs_rf = GridSearchCV(rf_pipe,
                            param_grid=params,
                            scoring=BSS_scorer,
                            refit=True,
                            cv=5,
                            n_jobs=-1,
                          verbose=4)

gs_rf.fit(X_train, y_train)
y_pred_gs=gs_rf.predict(X_test)

print(gs_rf.best_params_)
print(gs_rf.best_score_)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# {'calibrated_rf__base_estimator__class_weight': {1: 3, 0: 1}, 'calibrated_rf__base_estimator__max_depth': 18, 'calibrated_rf__base_estimator__max_features': 'sqrt', 'calibrated_rf__base_estimator__min_samples_leaf': 1, 'calibrated_rf__base_estimator__min_samples_split': 11, 'calibrated_rf__base_estimator__n_estimators': 68, 'calibrated_rf__method': 'isotonic'}
# 0.07616450575397413

# %%
np.arange(2,4)
# Out:
# array([2, 3])

# %% [markdown]
# ## XGBoost

# %%
#XGBoost base

calibrated_xgb = CalibratedClassifierCV(base_estimator=XGBClassifier(random_state=42))

cv_pipe = Pipeline([
            ('preprocessor', preprocessor),
            #('poly', polynomial),
            ('calibrated_xgb', calibrated_xgb)
            ])

scores = cross_validate(cv_pipe, X_train, y_train, cv=5, scoring=(BSS_scorer))

# %%
#mean BSS of XGB base
np.mean(scores['test_score'])
# Out:
# 0.020908023007475563

# %%
#XGB RandomSearchCV calibrated

# classweights = []
# for n in np.arange(1,11):
#     classweights.append({1 : n, 0 : 1})    

max_features = [None, 'sqrt', 'log2']
    
n_estimators = np.logspace(1.5, 3.5, num=8, dtype = int)

# Maximum number of levels in tree
max_depth = np.linspace(10, 110, num = 5, dtype = int)
max_depth = np.append(max_depth, None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]

calibrated_xgb = CalibratedClassifierCV(base_estimator=XGBClassifier(random_state=42))        

method=['sigmoid', 'isotonic']  

xgb_pipe = Pipeline([
        ('preprocessor', preprocessor),
        ('poly', polynomial),
        #('oversampling', over_sampling.SMOTE()),
        #('undersampling', under_sampling.NeighbourhoodCleaningRule()),
        ('calibrated_xgb', calibrated_xgb)
        ])

params = [{
        #'oversampling__sampling_strategy':ratios,
        #'oversampling__random_state':[42],
        #'undersampling__sampling_strategy':['majority'],
        #'undersampling__n_neighbors':np.arange(1,10),
        'calibrated_xgb__base_estimator__max_depth': [5,6,7],
        'calibrated_xgb__base_estimator__learning_rate': [0.1],
        'calibrated_xgb__base_estimator__gamma': [0],
        'calibrated_xgb__base_estimator__reg_lambda': [0],
        'calibrated_xgb__base_estimator__scale_pos_weight': [1, 3, 5],
        'calibrated_xgb__base_estimator__subsample': [0.9],
        'calibrated_xgb__base_estimator__colsample_bytree': [0.6, 0.65, 0.7],
        'calibrated_xgb__method':method
          }]

rd_xgb = RandomizedSearchCV(xgb_pipe,
                            param_distributions=params,
                            scoring=BSS_scorer,
                            refit=True,
                            cv=5,
                            n_iter=30,
                            n_jobs=-1,
                           random_state=42,
                          verbose=2)

rd_xgb.fit(X_train, y_train)
y_pred_gs=rd_xgb.predict(X_test)

print(rd_xgb.best_params_)
print(rd_xgb.best_score_)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# {'calibrated_xgb__method': 'isotonic', 'calibrated_xgb__base_estimator__subsample': 0.9, 'calibrated_xgb__base_estimator__scale_pos_weight': 1, 'calibrated_xgb__base_estimator__reg_lambda': 0, 'calibrated_xgb__base_estimator__max_depth': 6, 'calibrated_xgb__base_estimator__learning_rate': 0.1, 'calibrated_xgb__base_estimator__gamma': 0, 'calibrated_xgb__base_estimator__colsample_bytree': 0.65}
# 0.06113779800462045

# %%
#XGB GridSearchCV calibrated  

calibrated_xgb = CalibratedClassifierCV(base_estimator=XGBClassifier(random_state=42))        

method=['sigmoid', 'isotonic']  

xgb_pipe = Pipeline([
        ('preprocessor', preprocessor),
        #('poly', polynomial),
        #('oversampling', over_sampling.SMOTE()),
        #('undersampling', under_sampling.NeighbourhoodCleaningRule()),
        ('calibrated_xgb', calibrated_xgb)
        ])

params = [{#'oversampling__sampling_strategy':ratios,
           #'oversampling__random_state':[42],
        #'undersampling__sampling_strategy':['majority'],
        #'undersampling__n_neighbors':[187],
        'calibrated_xgb__base_estimator__max_depth': [6],
        'calibrated_xgb__base_estimator__learning_rate': [0.005,0.01,0.015],
        'calibrated_xgb__base_estimator__gamma': [0.1],
        'calibrated_xgb__base_estimator__reg_lambda': [0],
        'calibrated_xgb__base_estimator__scale_pos_weight': [2],
        'calibrated_xgb__base_estimator__subsample': [0.9],
        'calibrated_xgb__base_estimator__colsample_bytree': [0.65],
        'calibrated_xgb__method':['isotonic'] 
          }]

gs_xgb = GridSearchCV(xgb_pipe,
                            param_grid=params,
                            scoring=BSS_scorer,
                            refit=True,
                            cv=5,
                            n_jobs=-1,
                          verbose=4)

gs_xgb.fit(X_train, y_train)
y_pred_gs=gs_xgb.predict(X_test)

print(gs_xgb.best_params_)
print(gs_xgb.best_score_)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# {'calibrated_xgb__base_estimator__colsample_bytree': 0.65, 'calibrated_xgb__base_estimator__gamma': 0.1, 'calibrated_xgb__base_estimator__learning_rate': 0.005, 'calibrated_xgb__base_estimator__max_depth': 6, 'calibrated_xgb__base_estimator__reg_lambda': 0, 'calibrated_xgb__base_estimator__scale_pos_weight': 2, 'calibrated_xgb__base_estimator__subsample': 0.9, 'calibrated_xgb__method': 'isotonic'}
# 0.07512529472014359

# %% [markdown]
# ## SVC

# %%
#SVC base

calibrated_svc = CalibratedClassifierCV(base_estimator=SVC())

cv_pipe = Pipeline([
('preprocessor', preprocessor),
#('poly', polynomial),
('calibrated_svc', calibrated_svc)])

scores = cross_validate(cv_pipe, X_train, y_train, cv=5, scoring=(BSS_scorer))

# %%
np.mean(scores['test_score'])
# Out:
# 0.007114369470521043

# %%
#SVC RandomSearchCV calibrated

classweights = []
for n in np.arange(4,10,2):
    classweights.append({1 : n, 0 : 1})    

kernels = ['linear', 'rbf', 'poly']
    
gammas = [0.1, 1, 10, 100]

cs = [0.1, 1, 10, 100, 1000]

degrees = [2, 3, 4, 5, 6]

method=['sigmoid', 'isotonic']  

calibrated_svc = CalibratedClassifierCV(base_estimator=SVC(random_state=42))      

svc_pipe = Pipeline([
        ('preprocessor', preprocessor),
        #('oversampling', over_sampling.SMOTE()),
         #('undersampling', under_sampling.NeighbourhoodCleaningRule()),
        ('calibrated_svc', calibrated_svc)
        ])

params = [{
        #'oversampling__sampling_strategy':ratios,
        #'oversampling__random_state':[42],
        # 'undersampling__sampling_strategy':['majority'],
         #'undersampling__n_neighbors':np.arange(80,150),
        'calibrated_svc__base_estimator__kernel': ['rbf'],
        'calibrated_svc__base_estimator__C': [0.1, 1, 10, 20],
        'calibrated_svc__base_estimator__gamma': [0.01,,0.05,0.1],
        #'calibrated_svc__base_estimator__degree': degrees,
        'calibrated_svc__base_estimator__class_weight': classweights,
        'calibrated_svc__method':['isotonic'] 
          }]

rd_svc = RandomizedSearchCV(svc_pipe,
                            param_distributions=params,
                            scoring=BSS_scorer,
                            refit=True,
                            cv=5,
                            n_iter=30,
                            n_jobs=-1,
                           random_state=42,
                          verbose=3)

rd_svc.fit(X_train, y_train)
y_pred_gs=rd_svc.predict(X_test)

print(rd_svc.best_params_)
print(rd_svc.best_score_)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# {'calibrated_svc__method': 'isotonic', 'calibrated_svc__base_estimator__kernel': 'rbf', 'calibrated_svc__base_estimator__gamma': 0.01, 'calibrated_svc__base_estimator__class_weight': {1: 5, 0: 1}, 'calibrated_svc__base_estimator__C': 10}
# 0.0692580903221428

# %%
#SVC GridSearchCV calibrated

classweights = []
for n in np.arange(9,13):
    classweights.append({1 : n, 0 : 1})    

kernels = ['linear', 'rbf', 'poly']
    
gammas = [0.1, 1, 10, 100]

cs = [0.1, 1, 10, 100, 1000]

degrees = [2, 3, 4, 5, 6]

calibrated_svc = CalibratedClassifierCV(base_estimator=SVC(random_state=42))      

svc_pipe = Pipeline([
        ('preprocessor', preprocessor),
        #('poly', polynomial),
        #('oversampling', over_sampling.SMOTE()),
        #('undersampling', under_sampling.NeighbourhoodCleaningRule()),
        ('calibrated_svc', calibrated_svc)
        ])

params = [{
        #'oversampling__sampling_strategy':ratios,
        #'oversampling__random_state':[42],
        # 'undersampling__sampling_strategy':['majority'],
         #'undersampling__n_neighbors':np.arange(80,150),
        'calibrated_svc__base_estimator__kernel': ['rbf'],
        'calibrated_svc__base_estimator__C': [0.4, 0.5],
        'calibrated_svc__base_estimator__gamma': [0.001,0.005,0.01],
        #'calibrated_svc__base_estimator__degree': degrees,
        'calibrated_svc__base_estimator__class_weight': classweights,
        'calibrated_svc__method':['isotonic'] 
          }]

gs_svc = GridSearchCV(svc_pipe,
                    param_grid=params,
                    scoring=BSS_scorer,
                    refit=True,
                    cv=5,
                    n_jobs=-1,
                    verbose=3)

gs_svc.fit(X_train, y_train)
y_pred_gs=gs_svc.predict(X_test)

print(gs_svc.best_params_)
print(gs_svc.best_score_)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# {'calibrated_svc__base_estimator__C': 0.5, 'calibrated_svc__base_estimator__class_weight': {1: 9, 0: 1}, 'calibrated_svc__base_estimator__gamma': 0.01, 'calibrated_svc__base_estimator__kernel': 'rbf', 'calibrated_svc__method': 'isotonic'}
# 0.08319808610063259

# %%
#brier score on testing set
bs=brier_score_loss(y_test, gs_svc.predict_proba(X_test)[:,1])
1.0 - (bs / brier_ref)
# Out:
# 0.11281787861391557

# %% [markdown]
# ## Prepare for Streamlit

# %%
X_test_proba=gs_svc.predict_proba(X_test)[:,1]

# %%
import pickle
pickle.dump(gs_svc, open('stroke_gs_svc.pkl', 'wb'))

# %%
pickle.dump(X_test_proba, open('X_test_proba.pkl', 'wb'))

# %%
from scipy.stats import percentileofscore
percentile=percentileofscore(X_test_proba, 0.2)

# %%
prediction_proba=0.2

# %%
fig=sns.histplot(data=gs_svc.predict_proba(X_test)[:,1])
#plot where the patient proba lands
plt.vlines(0.2, 0, 500, color='r', label='', colors="r")
plt.annotate(str(round(percentile, 2))+'% percentile', xy=(prediction_proba+0.05, 300), weight='bold', color='r',
             xytext=(prediction_proba+0.1, 400), fontsize=15, arrowprops=dict(arrowstyle="->", color='r'))
# Out:
# Text(0.30000000000000004, 400, '97.55% percentile')

# %%
sns.histplot(y_test)
# Out:
# <AxesSubplot:xlabel='stroke', ylabel='Count'>
